# %% [markdown]
# ## North Carolina Public Schools Education Data Mini Project
# ## Logistic Regression Model and Support Vector Machines

# %% [markdown]
# ## Introduction(please feel free to edit.)
#
#
# In our previous project, we explored the North Carolina Public High Schools Dataset and visualized how school features are correlated with college enrollment percentage. There are several interesting findings from last project: from school education only, school features such as school fundings, school performance, school environment, teacher experience level, teacher qualification level are all affecting student performance in terms of SAT score and college enrollment percentage.
#
# In this project, we will create a binary response variable: a value of 1 represents the class that a student graduates from a certain school with certain features is likely going to college and a value of 0 represents the class that not likely going to college.Then we are going to select features like school fundings, school performance, school environment, teacher experience level, teacher qualification level. At last we will dive into using Logistic Regression and Support Vector Machines (SVMs) techniques to figure out the school factors that affect the college enrollment.

# %% [markdown]
# ## Analysis Strategy(please feel free to edit.)
#
# We orginally wanted to explore how school features can affect the possibility of a student going to college. But a binary response is not in the original data set. Thus, we decided to focus on college enrollment percentage with gender division.We arrive at a binary variable as the response:**ENROLL_sch_pct**.
#
# All the class 1 in the analysis represents the class that a student graduates from a certain school with certain features is likely going to college.
#
# With selected school features and classification techniques, we will give conclusions of the following questions:
#
# (placeholder here and it is just a thought that I have)
#
# we can get the conclision first, then come back to fill in the questions.

# %% [markdown]
# ## Library Loading & Data Preparation(please feel free to edit)
#
# -  **Question of interest**:
# Predict the chance of a school student's college enrollment.
#
# -  **Dataset transformation**:
# The orginial dataset *df_final* has two attributes for enrollment rates , *F_Female_ENROLL_sch_pct* and *M_Male_ENROLL_sch_pct* , which represent female and male students college enrollment rate accordingly. We need to combind these two variables together for analysis. We unpivot the dataset by melting the table with these two atrributes as value variables and other attributes as id variabels.
#
# Then we got a dataset with double rows and an additional column for gender indicator for college enrollment.
# Then we create two new binary attributes for gender indicator(*binary_gender_ENROLL_sch*) and college enrollment indicator(*ENROLL_sch_pct*).
#
# **ENROLL_sch_pct** is our response variable for the model.

# %%
# CODE REFERENCE: https://github.com/jakemdrew/EducationDataNC
# Alteration from reference code include removal of schoolYear as these will be fixed years in the following section. 
#import required Libraries
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************

#Location where copies of the raw data files will be downloaded and saved as csv files.
#directory = 'C:\\python_Files\\MSDS7331_DataMining\\Project\\data\\'

#### Reference: Snippets of this code block was taken directly from Eric Larson git repository: https://github.com/eclarson ####
#### Reference: https://stackoverflow.com/questions/12555323/adding-new-column-to-existing-dataframe-in-python-pandas

df_2014ML = pd.read_csv('PublicHighSchools2014_ML.csv') # read in the csv file
df_2014ML['year'] = 2014
# print('*********************************Before: 2014 Public High School Data*********************************')
# df_2014ML.info(verbose=False)

df_2015ML = pd.read_csv('PublicHighSchools2015_ML.csv') # read in the csv file 
df_2015ML['year'] = 2015
# print('*********************************Before: 2015 Public High School Data*********************************')
# df_2015ML.info(verbose=False)

df_2016ML = pd.read_csv('PublicHighSchools2016_ML.csv') # read in the csv file 
df_2016ML['year'] = 2016
# print('*********************************Before: 2016 Public High School Data*********************************')
# df_2016ML.info(verbose=False)

df_2017ML = pd.read_csv('PublicHighSchools2017_ML.csv') # read in the csv file 
df_2017ML['year'] = 2017
# print('*********************************Before: 2017 Public High School Data*********************************')
# df_2017ML.info(verbose=False)

#Combine data
#### Reference https://pandas.pydata.org/pandas-docs/stable/merging.html
df_final = pd.concat([df_2014ML,df_2015ML,df_2016ML,df_2017ML], axis=0, join='inner', ignore_index=True)
# print('*********************************After: Combined Public High School Data*********************************')
# print('*********************************Verbose=True to show all column names and type of data********************')
# df_final.info(verbose=True)

# Write to local as csv format. Commented out for now, but here as a placeholder for us to use sometimes. 
#df_final.to_csv(directory + 'df_final.csv', sep=',', index=False)

print("Highschool Dataset Prepared")
# Out:
# Highschool Dataset Prepared

# %%
# describe of two response variables :F_Female_ENROLL_sch_pct,M_Male_ENROLL_sch_pct
df_final[['F_Female_ENROLL_sch_pct','M_Male_ENROLL_sch_pct']].describe().transpose()
# Out:
#                           count       mean        std  min        25%  \
# F_Female_ENROLL_sch_pct  1904.0  40.513978  21.467421  0.0  28.163798
# M_Male_ENROLL_sch_pct    1904.0  31.998886  19.458767  0.0  20.754717
#
#                                50%        75%   max
# F_Female_ENROLL_sch_pct  34.587017  53.176250  95.0
# M_Male_ENROLL_sch_pct    26.884256  38.213056  95.0

# %% [markdown]
# ## Preparing dataset for logistic and SMV models
#
# ### Question of interest:
# Predict the chance of a school student's college enrollment.
#
# ### Dataset transformation
# The orginial dataset *df_final* has two attributes for enrollment rates , *F_Female_ENROLL_sch_pct* and *M_Male_ENROLL_sch_pct* , which represent female and male students college enrollment rate accordingly. We need to combind these two variables together for analysis. We unpivot the dataset by melting the table with these two atrributes as value variables and other attributes as id variabels.
#
# Then we got a dataset with double rows and an additional column for gender indicator for college enrollment.
# Then we create two new binary attributes for gender indicator(*binary_gender_ENROLL_sch*) and college enrollment indicator(*ENROLL_sch_pct*).
#
# ***ENROLL_sch_pct*** is our response variable for the model.

# %%
# Unpivots df_final on F_Female_ENROLL_sch_pct and M_Male_ENROLL_sch_pct
# to create a gender_college_enroll for college enrollment model

valuevar = ["F_Female_ENROLL_sch_pct","M_Male_ENROLL_sch_pct"]
idvar = list(df_final)
idvar.remove('F_Female_ENROLL_sch_pct')
idvar.remove('M_Male_ENROLL_sch_pct')

df_operation = pd.melt(df_final, id_vars = idvar,                                            
                        value_vars=valuevar,
                        var_name='gender_college_enroll', value_name='ENROLL_sch_pct')
df_operation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3808 entries, 0 to 3807
# Columns: 288 entries, student_num to ENROLL_sch_pct
# dtypes: float64(265), int64(22), object(1)
# memory usage: 8.4+ MB

# %%
#  Binary attributes for college enrollment of female and male.
#  binary_F_Female_ENROLL_sch_pct,binary_M_Male_ENROLL_sch_pct
#  1: College Enrollment Percentage larger than 0.5; 
#  0: College Enrollment Percentage smaller than 0.5

def f(row):
    if row['gender_college_enroll'] == 'F_Female_ENROLL_sch_pct':
        val = 1
    else:
        val = 0
    return val
df_operation['binary_gender_ENROLL_sch'] = df_operation.apply(f, axis=1)


def f(row):
    if row['ENROLL_sch_pct'] > 0.5:
        val = 1
    else:
        val = 0
    return val
df_operation['binary_ENROLL_sch_pct'] = df_operation.apply(f, axis=1)

# %% [markdown]
# ## Feature Selection
#
# ### Feature Selection Overview.
#
# After concatinating datasets from 2014 to 2017, we realize that there are in total 228 attributes. Thus, we will narrow down the attributes for classfication process.
#
# - The feature selection has two part:
#
# 1.Recursive Feature Elimination by keeping 20 attirubtes from the original.
#
# 2.Manully selected features that we consider may affect college enrollment from the following four aspects:
#
#
# -  school funding attirubtes

# %% [markdown]
# |     Column Name     |      Description     |
# |     :-     |     -------------:     |     :-:
# |     lea_avg_student_num     |Average school size within the LEA
# |     lea_total_expense_num     |Total expense (Dollars Spent) at LEA level
# |     lea_salary_expense_pct     |Percent of expense spent on Salaries at LEA level
# |     lea_services_expense_pct     |Percent of expense spent on Services at LEA level
# |     lea_supplies_expense_pct     |Percent of expense spent on Supplies at LEA level
# |     lea_instruct_equip_exp_pct     |Percent of expense spent on Instructional Equipment at LEA
# |     lea_federal_perpupil_num     |Federal expense per pupil at LEA level
# |     lea_local_perpupil_num     |Local expense per pupil at LEA level
# |     lea_state_perpupil_num     |State expense per pupil at LEA level

# %% [markdown]
# -  school performance, school environment & student scores attributes:

# %% [markdown]
# |     Column Name     |      Description     |
# |     :-     |     -------------:     |     :-:
# |     SPG Score     |school performace grades(numeric)
# |     EVAAS Growth Score     |EVVAS: provide a score to evaluate the education effectiveness
# |     sat_avg_score_num     |Average SAT Score (Critical Reading plus Math) at the School Level
# |     sat_participation_pct     |Percentage of High School Seniors taking the SAT at the School Level
# |     ap_participation_pct     |Percentage of High School Students taking an AP exam at the School Level
# |     ap_pct_3_or_above     |Percentage of Advanced Placement Exams with Scores of 3 or Above at the School Level
# |     total_specialized_courses     |Percent of students enrolled in at least one specialized course(CTE, AP/IB, Community College or University academic course) at the school level
# |     univ_college_courses     |Percent of students enrolled in at least one academic course at a community college or university at the school level
# |     avg_daily_attend_pct     |Average daily attendance percentage at school level
# |     crime_per_c_num     |	Number of crimes or acts of violence per 100 students at School level
# |     short_susp_per_c_num     |Short term suspensions per 100 students at school level
# |     long_susp_per_c_num     |Long term suspensions per 100 students at School Level
# |     expelled_per_c_num     |Expulsions per 100 students at School Level
# |     stud_internet_comp_num     |Ratio of students to internet connected computer at school level

# %% [markdown]
# -  teacher experience & teacher qualifications attributes:

# %% [markdown]
# |     Column Name     |      Description     |
# |     :-     |     -------------:     |     :-:
# |     flicensed_teach_pct     |Percent of teachers that meet NC fully licensed definition at school level
# |     tchyrs_0thru3_pct     |teaching experience year from 0-3 percentage
# |     tchyrs_4thru10_pct     |teaching experience year from 4-10 percentage
# |     tchyrs_11plus_pct     |teaching experience year 11+ percentage
# |     advance_dgr_pct     |Percent of teachers with masters or higher degree at school level
# |     _1yr_tchr_trnovr_pct     |One Year Teacher turnover percentage at school level
# |     0-3 Years_LEA_Exp_Pct_Prin     |Percentage of principals at a 0-3 years of experience level at the district level
# |     10+ Years_LEA_Exp_Pct_Prin     |Percentage of principals at a 10+ years of experience level at the district level
# |     4-10 Years_LEA_Exp_Pct_Prin     |Percentage of principals at a 4-10 years of experience level at the district level

# %% [markdown]
# -  minority division attributes:

# %% [markdown]
# |     Column Name     |      Description     |
# |     :-     |     -------------:     |     :-:
# |     GraduationRate_4yr_Female     |GraduationRate 4 years for female
# |     GraduationRate_4yr_Male     |GraduationRate 4 years for male
# |     GraduationRate_5yr_All     |GraduationRate 5 years for all
# |     GraduationRate_5yr_Female     |GraduationRate 5 years for female
# |     GraduationRate_5yr_Male     |GraduationRate 5 years for male
# |     GraduationRate_4yr_Asian     |GraduationRate 4 years for Asians
# |     GraduationRate_5yr_Asian     |GraduationRate 5 years for Asians
# |     GraduationRate_4yr_Black     |GraduationRate 4 years for Black
# |     GraduationRate_5yr_Black     |GraduationRate 5 years for Black
# |     GraduationRate_4yr_Hispanic     |GraduationRate 4 years for Hispanic
# |     GraduationRate_5yr_Hispanic     |GraduationRate 5 years for Hispanic
# |     GraduationRate_4yr_TwoorMoreRaces     |GraduationRate 4 years for TwoorMoreRaces
# |     GraduationRate_5yr_TwoorMoreRaces     |GraduationRate 5 years for TwoorMoreRaces
# |     GraduationRate_4yr_White     |GraduationRate 4 years for White
# |     GraduationRate_5yr_White     |GraduationRate 5 years for White
# |     GraduationRate_4yr_EDS     |GraduationRate 4 years for Economically Disadvantaged
# |     GraduationRate_5yr_EDS     |GraduationRate 5 years for Economically Disadvantaged
# |     GraduationRate_4yr_LEP     |GraduationRate 4 years for Limited English Proficiency
# |     GraduationRate_5yr_LEP     |GraduationRate 5 years for Limited English Proficiency
# |     GraduationRate_4yr_SWD     |GraduationRate 4 years for Students With Disabilities
# |     GraduationRate_5yr_SWD     |GraduationRate 5 years for Students With Disabilities
# |     GraduationRate_4yr_AIG     |GraduationRate 4 years for Academically/Intellectually Gifted
# |     GraduationRate_5yr_AIG     |GraduationRate 5 years for Academically/Intellectually Gifted
# |     MinorityFemalePct     |percentage of certain subgroups, female
# |     MinorityMalePct     |percentage of certain subgroups, male
# |     MinorityPct     |percentage of certain subgroups
# |     TwoOrMorePct     |percentage of certain subgroups

# %% [markdown]
# ### Recursive Feature Elimination.
#
# **The Recursive Feature Elimination (RFE)** method is a feature selection approach. It works by recursively removing attributes and building a model on those attributes that remain. It uses the model accuracy to identify which attributes (and combination of attributes) contribute the most to predicting the target attribute.
#
# We use RFE to select 20 explanation attributes for the model.
#
# The final selected features are as shown:
#
# |     Column Name     |      Description     |
# |     :-     |     -------------:     |     :-:
# |     binary_gender_ENROLL_sch     |binary response created last step, if female, the cell will have value of 1
# |     MathGr10_pTarget_PctMet     |percentage of meeting the math grade 10 target
# |     lea_nbpts_num     |Average number of National Board Certified staff at LEA level
# |     ACTWorkKeys_SilverPlus_Asian     |Silver or Better Certificate Asian
# |     ACTMath_ACTBenchmark_Black     |Silver or Better Certificate Black
# |     10+ Years_LEA_Exp_Pct_Prin     |Percentage of principals at a 10+ years of experience level at the district level
# |     ECODIS_Economically Disadvantaged_ENROLL_sch_pct     |percentage of economicaly disadvantaged students enrolled
# |     Accomplished_TCHR_Standard 3_Pct     |percentage of teacher that have level of accomplished and standard 3|
# |     GraduationRate_5yr_White     |GraduationRate 5 years for White
# |     Distinguished_TCHR_Standard 1_Pct     |percentage of teacher that have level of distinguished and standard 1
# |     ACTCompositeScore_UNCMin_AmericanIndian     |ACT Composite Score, Met UNC Minimum,American Indian
# |     Distinguished_TCHR_Standard 4_Pct     |percentage of teacher that have level of distinguished and standard 4
# |     Distinguished_TCHR_Standard 5_Pct     |percentage of teacher that have level of distinguished and standard 5
# |     calendar_type_txt_Regular School, Year-Round Calendar     |Description of school calendar and school type,regular school, binary
# |     ACTMath_ACTBenchmark_LEP     |ACT math benchmarks for Limited English Proficiency
# |     ACTScience_ACTBenchmark_EDS     |ACT science benchmarks for Economically Disadvantaged
# |     lea_univ_college_courses     |Percent of students enrolled in at least one academic course at a community college or university at the LEA level
# |     SPG Grade_B     |SPG score with grade B
# |     ACTWriting_ACTBenchmark_LEP     |ACT writing benchmarks for Limited English Proficiency
# |     ACT_pTarget_PctMet     |ACT target percentage met

# %% [markdown]
# The following is to create the RFE model to select attributes.

# %%
#check for class bias based on our thresholds used.  
df_operation['binary_ENROLL_sch_pct'].value_counts()
# Out:
# 1    3583
# 0     225
# Name: binary_ENROLL_sch_pct, dtype: int64

# %%
# Build up response and explanatory variables for later model fitting
df_target = df_operation.binary_ENROLL_sch_pct
df_feat = df_operation.drop(['binary_ENROLL_sch_pct','ENROLL_sch_pct','gender_college_enroll'], axis=1)

# %% [markdown]
# ## Logistic Regression Feature Selection.
#
# ***The Recursive Feature Elimination (RFE)*** method is a feature selection approach. It works by recursively removing attributes and building a model on those attributes that remain. It uses the model accuracy to identify which attributes (and combination of attributes) contribute the most to predicting the target attribute.
#
# We use RFE to select 20 explanation attributes for the model.

# %%
# Code reference: https://machinelearningmastery.com/feature-selection-in-python-with-scikit-learn/
# Reference: http://scikit-learn.org/stable/modules/feature_selection.html
# Recursive Feature Elimination
# This section might take a few minutes

from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE as rfe

# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select attributes count that wish to keep in the model
keep_attributes = 20 
rfe = rfe(model, keep_attributes)
rfe = rfe.fit(df_feat, df_target)
# summarize the selection of the attributes
#print(rfe.support_)
#print(rfe.ranking_)

# Set display parameter
#pd.set_option('display.height', 300) # 'display.height' is no longer option in RFE library so commented out
pd.set_option('display.max_rows', 300)

# Create dataframe for feature selection output. 
# Selected attributes: Support = true
df_column = list(df_feat)
df_column_selection = pd.DataFrame()
df_column_selection['column']=df_column
df_column_selection['support']=rfe.support_
df_column_selection['ranking']=rfe.ranking_

print(df_column_selection.sort_values('ranking',ascending=True))
# Out:
#                                                 column  support  ranking
# 286                           binary_gender_ENROLL_sch     True        1
# 51                        ACTWorkKeys_SilverPlus_Asian     True        1
# 38             ACTCompositeScore_UNCMin_AmericanIndian     True        1
# 125                        ACTEnglish_ACTBenchmark_LEP     True        1
# 126                           ACTMath_ACTBenchmark_LEP     True        1
# 128                        ACTScience_ACTBenchmark_LEP     True        1
# 131                        ACTWriting_ACTBenchmark_LEP     True        1
# 171                                 ACT_pTarget_PctMet     True        1
# 174                            MathGr10_pTarget_PctMet     True        1
# 189                                    lea_cte_courses     True        1
# 19                            ACTMath_ACTBenchmark_All     True        1
# 190                           lea_univ_college_courses     True        1
# 191   ECODIS_Economically Disadvantaged_ENROLL_sch_pct     True        1
# 30                           ACTMath_ACTBenchmark_Male     True        1
# 203                         lea_stud_internet_comp_num     True        1
# 279                                        SPG Grade_B     True        1
# 276  calendar_type_txt_Regular School, Year-Round C...     True        1
# 197                             stud_internet_comp_num     True        1
# 237                  Distinguished_TCHR_Standard 4_Pct     True        1
# 234                  Distinguished_TCHR_Standard 1_Pct     True        1
# 60                          ACTMath_ACTBenchmark_Black    False        2
# 23                              GraduationRate_5yr_All    False        3
# 235                  Distinguished_TCHR_Standard 2_Pct    False        4
# 65                       ACTWriting_ACTBenchmark_Black    False        5
# 59                       ACTEnglish_ACTBenchmark_Black    False        6
# 100                      ACTScience_ACTBenchmark_White    False        7
# 14                                           SPG Score    False        8
# 42              ACTWriting_ACTBenchmark_AmericanIndian    False        9
# 103                      ACTWriting_ACTBenchmark_White    False       10
# 21                         ACTWriting_ACTBenchmark_All    False       11
# 217                                      lea_nbpts_num    False       12
# 107                             EOCSubjects_CACR_White    False       13
# 16                                    English II Score    False       14
# 76                    ACTScience_ACTBenchmark_Hispanic    False       15
# 110                       ACTCompositeScore_UNCMin_EDS    False       16
# 79                    ACTWriting_ACTBenchmark_Hispanic    False       17
# 117                        ACTWriting_ACTBenchmark_EDS    False       18
# 22                                EOCSubjects_CACR_All    False       19
# 225                   Accomplished_TCHR_Standard 2_Pct    False       20
# 17                                       Biology Score    False       21
# 114                        ACTScience_ACTBenchmark_EDS    False       22
# 44                     EOCEnglish2_CACR_AmericanIndian    False       23
# 5                                          Math I_Size    False       24
# 104                              EOCBiology_CACR_White    False       25
# 108                           GraduationRate_4yr_White    False       26
# 36                             GraduationRate_4yr_Male    False       27
# 152                               EOCEnglish2_CACR_SWD    False       28
# 35                               EOCEnglish2_CACR_Male    False       29
# 3                                         Biology_Size    False       30
# 67                              EOCEnglish2_CACR_Black    False       31
# 146                        ACTScience_ACTBenchmark_SWD    False       32
# 228                   Accomplished_TCHR_Standard 5_Pct    False       33
# 77                  ACTSubtests_BenchmarksMet_Hispanic    False       34
# 101                    ACTSubtests_BenchmarksMet_White    False       35
# 87                 ACTMath_ACTBenchmark_TwoorMoreRaces    False       36
# 132                                EOCBiology_CACR_LEP    False       37
# 92                      EOCBiology_CACR_TwoorMoreRaces    False       38
# 4                                      English II_Size    False       39
# 45                        EOCMathI_CACR_AmericanIndian    False       40
# 136                                  EOCMathI_CACR_LEP    False       41
# 82                              EOCMathI_CACR_Hispanic    False       42
# 121                               EOCSubjects_CACR_EDS    False       43
# 143                        ACTEnglish_ACTBenchmark_SWD    False       44
# 145                        ACTReading_ACTBenchmark_SWD    False       45
# 120                                  EOCMathI_CACR_EDS    False       46
# 29                           GraduationRate_5yr_Female    False       47
# 83                           EOCSubjects_CACR_Hispanic    False       48
# 47                   GraduationRate_4yr_AmericanIndian    False       49
# 85                         GraduationRate_5yr_Hispanic    False       50
# 158                             GraduationRate_5yr_SWD    False       51
# 58                      ACTCompositeScore_UNCMin_Black    False       52
# 222                         10+ Years_LEA_Exp_Pct_Prin    False       53
# 168                               EOCSubjects_CACR_AIG    False       54
# 124                       ACTCompositeScore_UNCMin_LEP    False       55
# 138                               EOCSubjects_CACR_LEP    False       56
# 139                                EOCSubjects_GLP_LEP    False       57
# 99                          ACTMath_ACTBenchmark_White    False       58
# 148                         ACTWorkKeys_SilverPlus_SWD    False       59
# 89            ACTSubtests_BenchmarksMet_TwoorMoreRaces    False       60
# 32                         ACTWorkKeys_SilverPlus_Male    False       61
# 282                            EVAAS Growth Status_Met    False       62
# 102                       ACTWorkKeys_SilverPlus_White    False       63
# 160                           ACTMath_ACTBenchmark_AIG    False       64
# 40            ACTSubtests_BenchmarksMet_AmericanIndian    False       65
# 161                        ACTScience_ACTBenchmark_AIG    False       66
# 94                        EOCMathI_CACR_TwoorMoreRaces    False       67
# 135                                EOCEnglish2_GLP_LEP    False       68
# 169                             GraduationRate_4yr_AIG    False       69
# 24                     ACTCompositeScore_UNCMin_Female    False       70
# 64                        ACTWorkKeys_SilverPlus_Black    False       71
# 122                             GraduationRate_4yr_EDS    False       72
# 70                            GraduationRate_4yr_Black    False       73
# 157                             GraduationRate_4yr_SWD    False       74
# 207                                  tchyrs_0thru3_pct    False       75
# 200                           lea_short_susp_per_c_num    False       76
# 88              ACTScience_ACTBenchmark_TwoorMoreRaces    False       77
# 170                             GraduationRate_5yr_AIG    False       78
# 72                   ACTCompositeScore_UNCMin_Hispanic    False       79
# 281                                        SPG Grade_D    False       80
# 113                        ACTReading_ACTBenchmark_EDS    False       81
# 140                             GraduationRate_4yr_LEP    False       82
# 73                    ACTEnglish_ACTBenchmark_Hispanic    False       83
# 78                     ACTWorkKeys_SilverPlus_Hispanic    False       84
# 209                                  tchyrs_11plus_pct    False       85
# 193                                    crime_per_c_num    False       86
# 166                               EOCEnglish2_CACR_AIG    False       87
# 172                         ACTWorkKeys_pTarget_PctMet    False       88
# 199                                lea_crime_per_c_num    False       89
# 106                                EOCMathI_CACR_White    False       90
# 105                             EOCEnglish2_CACR_White    False       91
# 173                      CurrentYearEOC_pTarget_PctMet    False       92
# 226                   Accomplished_TCHR_Standard 3_Pct    False       93
# 150                                EOCBiology_CACR_SWD    False       94
# 167                                  EOCMathI_CACR_AIG    False       95
# 69                              EOCSubjects_CACR_Black    False       96
# 109                           GraduationRate_5yr_White    False       97
# 175                         ReadingGr10_pTarget_PctMet    False       98
# 41               ACTWorkKeys_SilverPlus_AmericanIndian    False       99
# 57                            GraduationRate_5yr_Asian    False      100
# 61                       ACTReading_ACTBenchmark_Black    False      101
# 66                               EOCBiology_CACR_Black    False      102
# 118                                EOCBiology_CACR_EDS    False      103
# 154                                  EOCMathI_CACR_SWD    False      104
# 144                           ACTMath_ACTBenchmark_SWD    False      105
# 54                                 EOCMathI_CACR_Asian    False      106
# 52                               EOCBiology_CACR_Asian    False      107
# 84                         GraduationRate_4yr_Hispanic    False      108
# 18                                  ACT WorkKeys Score    False      109
# 163                         ACTWorkKeys_SilverPlus_AIG    False      110
# 184                                  ap_pct_3_or_above    False      111
# 74                       ACTMath_ACTBenchmark_Hispanic    False      112
# 151                                 EOCBiology_GLP_SWD    False      113
# 162                      ACTSubtests_BenchmarksMet_AIG    False      114
# 63                     ACTSubtests_BenchmarksMet_Black    False      115
# 283                         EVAAS Growth Status_NotMet    False      116
# 20                         ACTScience_ACTBenchmark_All    False      117
# 97                   GraduationRate_5yr_TwoorMoreRaces    False      118
# 111                        ACTEnglish_ACTBenchmark_EDS    False      119
# 177                        TotalTargets_pTarget_PctMet    False      120
# 216                              lea_tchyrs_11plus_pct    False      121
# 272                                grade_range_cd_9-13    False      122
# 194                               short_susp_per_c_num    False      123
# 127                        ACTReading_ACTBenchmark_LEP    False      124
# 227                   Accomplished_TCHR_Standard 4_Pct    False      125
# 271                                grade_range_cd_9-12    False      126
# 7                               lea_salary_expense_pct    False      127
# 186                          total_specialized_courses    False      128
# 55                              EOCSubjects_CACR_Asian    False      129
# 81                           EOCEnglish2_CACR_Hispanic    False      130
# 37                             GraduationRate_5yr_Male    False      131
# 90               ACTWorkKeys_SilverPlus_TwoorMoreRaces    False      132
# 179                              lea_sat_avg_score_num    False      133
# 206                                flicensed_teach_pct    False      134
# 238                  Distinguished_TCHR_Standard 5_Pct    False      135
# 268                                grade_range_cd_7-13    False      136
# 31                        ACTScience_ACTBenchmark_Male    False      137
# 115                      ACTSubtests_BenchmarksMet_EDS    False      138
# 123                             GraduationRate_5yr_EDS    False      139
# 153                                EOCEnglish2_GLP_SWD    False      140
# 180                              sat_participation_pct    False      141
# 25                      ACTEnglish_ACTBenchmark_Female    False      142
# 278                              Grad_project_status_Y    False      143
# 164                        ACTWriting_ACTBenchmark_AIG    False      144
# 159                       ACTCompositeScore_UNCMin_AIG    False      145
# 49                      ACTCompositeScore_UNCMin_Asian    False      146
# 233                     Developing_TCHR_Standard 5_Pct    False      147
# 264                               grade_range_cd_11-12    False      148
# 176                             SciGr11_pTarget_PctMet    False      149
# 215                             lea_tchyrs_4thru10_pct    False      150
# 214                              lea_tchyrs_0thru3_pct    False      151
# 221                         0-3 Years_LEA_Exp_Pct_Prin    False      152
# 50                     ACTSubtests_BenchmarksMet_Asian    False      153
# 187                                        cte_courses    False      154
# 195                                long_susp_per_c_num    False      155
# 243                     Proficient_TCHR_Standard 2_Pct    False      156
# 212                               _1yr_tchr_trnovr_pct    False      157
# 147                      ACTSubtests_BenchmarksMet_SWD    False      158
# 285                                               year    False      159
# 251                                           BlackPct    False      160
# 133                                 EOCBiology_GLP_LEP    False      161
# 39                 ACTMath_ACTBenchmark_AmericanIndian    False      162
# 129                      ACTSubtests_BenchmarksMet_LEP    False      163
# 185                              lea_ap_pct_3_or_above    False      164
# 86             ACTCompositeScore_UNCMin_TwoorMoreRaces    False      165
# 2                                   st_avg_student_num    False      166
# 245                     Proficient_TCHR_Standard 4_Pct    False      167
# 155                                   EOCMathI_GLP_SWD    False      168
# 91              ACTWriting_ACTBenchmark_TwoorMoreRaces    False      169
# 93                     EOCEnglish2_CACR_TwoorMoreRaces    False      170
# 137                                   EOCMathI_GLP_LEP    False      171
# 71                            GraduationRate_5yr_Black    False      172
# 0                                          student_num    False      173
# 230                     Developing_TCHR_Standard 2_Pct    False      174
# 165                                EOCBiology_CACR_AIG    False      175
# 266                                grade_range_cd_6-13    False      176
# 231                     Developing_TCHR_Standard 3_Pct    False      177
# 134                               EOCEnglish2_CACR_LEP    False      178
# 277                                      esea_status_P    False      179
# 249                                     BlackFemalePct    False      180
# 253                                    HispanicMalePct    False      181
# 96                   GraduationRate_4yr_TwoorMoreRaces    False      182
# 34                                EOCBiology_CACR_Male    False      183
# 43                      EOCBiology_CACR_AmericanIndian    False      184
# 142                       ACTCompositeScore_UNCMin_SWD    False      185
# 98                      ACTCompositeScore_UNCMin_White    False      186
# 244                     Proficient_TCHR_Standard 3_Pct    False      187
# 95                     EOCSubjects_CACR_TwoorMoreRaces    False      188
# 232                     Developing_TCHR_Standard 4_Pct    False      189
# 33                        ACTWriting_ACTBenchmark_Male    False      190
# 223                        4-10 Years_LEA_Exp_Pct_Prin    False      191
# 28                           GraduationRate_4yr_Female    False      192
# 236                  Distinguished_TCHR_Standard 3_Pct    False      193
# 250                                       BlackMalePct    False      194
# 75                    ACTReading_ACTBenchmark_Hispanic    False      195
# 255                                  MinorityFemalePct    False      196
# 116                         ACTWorkKeys_SilverPlus_EDS    False      197
# 265                                grade_range_cd_6-12    False      198
# 68                                 EOCMathI_CACR_Black    False      199
# 257                                        MinorityPct    False      200
# 119                               EOCEnglish2_CACR_EDS    False      201
# 156                               EOCSubjects_CACR_SWD    False      202
# 13                              lea_state_perpupil_num    False      203
# 26                       ACTWorkKeys_SilverPlus_Female    False      204
# 181                          lea_sat_participation_pct    False      205
# 220                            lea_emer_prov_teach_pct    False      206
# 280                                        SPG Grade_C    False      207
# 219                            lea_1yr_tchr_trnovr_pct    False      208
# 46                     EOCSubjects_CACR_AmericanIndian    False      209
# 27                             EOCEnglish2_CACR_Female    False      210
# 149                        ACTWriting_ACTBenchmark_SWD    False      211
# 12                              lea_local_perpupil_num    False      212
# 211                                    advance_dgr_pct    False      213
# 213                            lea_flicensed_teach_pct    False      214
# 8                             lea_services_expense_pct    False      215
# 205                                 st_crime_per_c_num    False      216
# 263                                       TwoOrMorePct    False      217
# 275                               grade_range_cd_PK-12    False      218
# 262                                   TwoOrMoreMalePct    False      219
# 201                            lea_long_susp_per_c_num    False      220
# 183                           lea_ap_participation_pct    False      221
# 53                              EOCEnglish2_CACR_Asian    False      222
# 192                               avg_daily_attend_pct    False      223
# 246                     Proficient_TCHR_Standard 5_Pct    False      224
# 252                                  HispanicFemalePct    False      225
# 182                               ap_participation_pct    False      226
# 273                                 grade_range_cd_9-9    False      227
# 188                               univ_college_courses    False      228
# 229                     Developing_TCHR_Standard 1_Pct    False      229
# 198                           lea_avg_daily_attend_pct    False      230
# 112                           ACTMath_ACTBenchmark_EDS    False      231
# 10                          lea_instruct_equip_exp_pct    False      232
# 6                                lea_total_expense_num    False      233
# 9                             lea_supplies_expense_pct    False      234
# 196                                 expelled_per_c_num    False      235
# 208                                 tchyrs_4thru10_pct    False      236
# 11                            lea_federal_perpupil_num    False      237
# 247                                     AsianFemalePct    False      238
# 204                            st_avg_daily_attend_pct    False      239
# 56                            GraduationRate_4yr_Asian    False      240
# 141                             GraduationRate_5yr_LEP    False      241
# 270                                grade_range_cd_9-11    False      242
# 248                                       AsianMalePct    False      243
# 130                         ACTWorkKeys_SilverPlus_LEP    False      244
# 218                                lea_advance_dgr_pct    False      245
# 254                                    IndianFemalePct    False      246
# 202                             lea_expelled_per_c_num    False      247
# 15                                  EVAAS Growth Score    False      248
# 256                                    MinorityMalePct    False      249
# 261                                 TwoOrMoreFemalePct    False      250
# 274                                grade_range_cd_K-12    False      251
# 62                       ACTScience_ACTBenchmark_Black    False      252
# 178                                  sat_avg_score_num    False      253
# 48                   GraduationRate_5yr_AmericanIndian    False      254
# 224                   Accomplished_TCHR_Standard 1_Pct    False      255
# 260                                   PacificIslandPct    False      256
# 1                                  lea_avg_student_num    False      257
# 259                               PacificIslandMalePct    False      258
# 80                            EOCBiology_CACR_Hispanic    False      259
# 240                Not Demostrated_TCHR_Standard 2_Pct    False      260
# 267                                grade_range_cd_7-12    False      261
# 269                                grade_range_cd_8-12    False      262
# 284                                          unit_code    False      263
# 210                                          nbpts_num    False      264
# 239                Not Demostrated_TCHR_Standard 1_Pct    False      265
# 258                             PacificIslandFemalePct    False      266
# 242                     Proficient_TCHR_Standard 1_Pct    False      267
# 241                Not Demostrated_TCHR_Standard 4_Pct    False      268

# %% [markdown]
# ### The Final Selected Features.
#
# After obtaining the features from Recursive Feature Elimination process, we combine them with the manually selected features to create the final seleted features for future analysis.

# %%
# Create dataset with auto-selected and manual-selected attributes for building logistic regression model

# auto selected columns from Logistic Regression Feature Selection
auto_selected_columns = df_column_selection.loc[df_column_selection['support'] == True]['column'].tolist()

# manually selected columns 

# school features
exp_list = ['lea_total_expense_num','lea_salary_expense_pct','lea_services_expense_pct','lea_supplies_expense_pct','lea_instruct_equip_exp_pct','lea_federal_perpupil_num','lea_local_perpupil_num','lea_state_perpupil_num']

# performance scores list
school_performace = ['SPG Score','EVAAS Growth Score','sat_avg_score_num','sat_participation_pct','ap_participation_pct','ap_pct_3_or_above','total_specialized_courses','univ_college_courses','avg_daily_attend_pct','crime_per_c_num','short_susp_per_c_num','long_susp_per_c_num','expelled_per_c_num','stud_internet_comp_num']

# teacher qualifications
teachers = ['flicensed_teach_pct','tchyrs_0thru3_pct','tchyrs_4thru10_pct','tchyrs_11plus_pct','advance_dgr_pct','_1yr_tchr_trnovr_pct','0-3 Years_LEA_Exp_Pct_Prin','10+ Years_LEA_Exp_Pct_Prin','4-10 Years_LEA_Exp_Pct_Prin']

# minority division
graduation_rate = ['GraduationRate_4yr_Female','GraduationRate_4yr_Male','GraduationRate_5yr_All','GraduationRate_5yr_Female','GraduationRate_5yr_Male','GraduationRate_4yr_Asian','GraduationRate_5yr_Asian','GraduationRate_4yr_Black','GraduationRate_5yr_Black','GraduationRate_4yr_Hispanic','GraduationRate_5yr_Hispanic','GraduationRate_4yr_TwoorMoreRaces','GraduationRate_5yr_TwoorMoreRaces','GraduationRate_4yr_White','GraduationRate_5yr_White','GraduationRate_4yr_EDS','GraduationRate_5yr_EDS','GraduationRate_4yr_LEP','GraduationRate_5yr_LEP','GraduationRate_4yr_SWD','GraduationRate_5yr_SWD','GraduationRate_4yr_AIG','GraduationRate_5yr_AIG']
minority_group = ['MinorityFemalePct','MinorityMalePct','MinorityPct','TwoOrMorePct']    

primary_keys = ['unit_code','year']

selected_columns = list(set().union(auto_selected_columns,exp_list,school_performace,teachers,graduation_rate,minority_group,primary_keys ))

df_feat = df_feat[selected_columns]
df_feat1 = df_feat[auto_selected_columns]
df_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3808 entries, 0 to 3807
# Data columns (total 79 columns):
# GraduationRate_4yr_Hispanic                              3808 non-null float64
# lea_total_expense_num                                    3808 non-null float64
# crime_per_c_num                                          3808 non-null float64
# ap_pct_3_or_above                                        3808 non-null float64
# GraduationRate_5yr_TwoorMoreRaces                        3808 non-null float64
# sat_participation_pct                                    3808 non-null float64
# calendar_type_txt_Regular School, Year-Round Calendar    3808 non-null int64
# avg_daily_attend_pct                                     3808 non-null float64
# GraduationRate_4yr_Female                                3808 non-null float64
# GraduationRate_5yr_Black                                 3808 non-null float64
# GraduationRate_5yr_AIG                                   3808 non-null float64
# unit_code                                                3808 non-null int64
# GraduationRate_5yr_Hispanic                              3808 non-null float64
# stud_internet_comp_num                                   3808 non-null float64
# GraduationRate_4yr_AIG                                   3808 non-null float64
# MinorityPct                                              3808 non-null float64
# lea_state_perpupil_num                                   3808 non-null float64
# GraduationRate_4yr_EDS                                   3808 non-null float64
# lea_stud_internet_comp_num                               3808 non-null float64
# lea_instruct_equip_exp_pct                               3808 non-null float64
# SPG Grade_B                                              3808 non-null int64
# GraduationRate_5yr_Female                                3808 non-null float64
# MinorityMalePct                                          3808 non-null float64
# ACTEnglish_ACTBenchmark_LEP                              3808 non-null float64
# GraduationRate_4yr_Asian                                 3808 non-null float64
# lea_local_perpupil_num                                   3808 non-null float64
# ACTWriting_ACTBenchmark_LEP                              3808 non-null float64
# ACTMath_ACTBenchmark_Male                                3808 non-null float64
# lea_salary_expense_pct                                   3808 non-null float64
# lea_univ_college_courses                                 3808 non-null float64
# GraduationRate_5yr_White                                 3808 non-null float64
# GraduationRate_5yr_EDS                                   3808 non-null float64
# binary_gender_ENROLL_sch                                 3808 non-null int64
# tchyrs_0thru3_pct                                        3808 non-null float64
# lea_supplies_expense_pct                                 3808 non-null float64
# _1yr_tchr_trnovr_pct                                     3808 non-null float64
# year                                                     3808 non-null int64
# short_susp_per_c_num                                     3808 non-null float64
# ap_participation_pct                                     3808 non-null float64
# tchyrs_4thru10_pct                                       3808 non-null float64
# 0-3 Years_LEA_Exp_Pct_Prin                               3808 non-null float64
# long_susp_per_c_num                                      3808 non-null float64
# ACTCompositeScore_UNCMin_AmericanIndian                  3808 non-null float64
# advance_dgr_pct                                          3808 non-null float64
# GraduationRate_4yr_Male                                  3808 non-null float64
# Distinguished_TCHR_Standard 4_Pct                        3808 non-null float64
# GraduationRate_4yr_Black                                 3808 non-null float64
# 4-10 Years_LEA_Exp_Pct_Prin                              3808 non-null float64
# GraduationRate_5yr_SWD                                   3808 non-null float64
# lea_federal_perpupil_num                                 3808 non-null float64
# ACTWorkKeys_SilverPlus_Asian                             3808 non-null float64
# sat_avg_score_num                                        3808 non-null float64
# total_specialized_courses                                3808 non-null float64
# univ_college_courses                                     3808 non-null float64
# ACTMath_ACTBenchmark_LEP                                 3808 non-null float64
# tchyrs_11plus_pct                                        3808 non-null float64
# GraduationRate_5yr_LEP                                   3808 non-null float64
# ACTScience_ACTBenchmark_LEP                              3808 non-null float64
# EVAAS Growth Score                                       3808 non-null float64
# MathGr10_pTarget_PctMet                                  3808 non-null float64
# GraduationRate_4yr_LEP                                   3808 non-null float64
# GraduationRate_5yr_Male                                  3808 non-null float64
# lea_cte_courses                                          3808 non-null float64
# ACTMath_ACTBenchmark_All                                 3808 non-null float64
# GraduationRate_4yr_TwoorMoreRaces                        3808 non-null float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct         3808 non-null float64
# flicensed_teach_pct                                      3808 non-null float64
# expelled_per_c_num                                       3808 non-null float64
# lea_services_expense_pct                                 3808 non-null float64
# GraduationRate_5yr_All                                   3808 non-null float64
# 10+ Years_LEA_Exp_Pct_Prin                               3808 non-null float64
# SPG Score                                                3808 non-null float64
# GraduationRate_4yr_White                                 3808 non-null float64
# MinorityFemalePct                                        3808 non-null float64
# TwoOrMorePct                                             3808 non-null float64
# GraduationRate_5yr_Asian                                 3808 non-null float64
# ACT_pTarget_PctMet                                       3808 non-null float64
# Distinguished_TCHR_Standard 1_Pct                        3808 non-null float64
# GraduationRate_4yr_SWD                                   3808 non-null float64
# dtypes: float64(74), int64(5)
# memory usage: 2.3 MB

# %% [markdown]
# ### Training and test dataset split

# %%
# from sklearn.model_selection import ShuffleSplit
# # we want to predict the X and y data as follows:
# if 'binary_F_Female_ENROLL_sch_pct' in df_logistic:
#     y = df_logistic['binary_F_Female_ENROLL_sch_pct'].values # get the labels we want
#     del df_logistic['binary_F_Female_ENROLL_sch_pct'] # get rid of the class label
#     x = df_logistic.values # use everything else to predict!

#     ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
#     #    have converted them into simple matrices to use with scikit learn
        
# # to use the cross validation object in scikit learn, we need to grab an instance
# #    of the object and set it up. This object will be able to split our data into 
# #    training and testing splits

# num_cv_iterations = 3
# num_instances = len(y)
# cv_object = ShuffleSplit(n_splits=num_cv_iterations,
#                          test_size  = 0.2)
                         
# print(cv_object)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_feat, df_target, test_size=0.20, random_state=3001)

# %% [markdown]
# ## Normalize the data

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# %% [markdown]
# ### Logistic Regression

# %%
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression

import seaborn as sns
from sklearn import metrics as mt

sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

lr_clf = LogisticRegression(penalty='l2', C=0.05) # 
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print('confusion matrix:\n',conf )

# Create dataframe for results.
zip_vars=pd.DataFrame()
zip_vars['column name']=df_feat.columns
zip_vars['weight']=lr_clf.coef_.T
# sort by weight and reset index of zip_vars
zip_vars = zip_vars.sort_values('weight',ascending=False)
zip_vars.reset_index(drop=True,inplace=True)
print(zip_vars)
# Out:
# accuracy: 0.9868766404199475
# confusion matrix:
#  [[ 29   7]
#  [  3 723]]
#                                           column name    weight
# 0    ECODIS_Economically Disadvantaged_ENROLL_sch_pct  0.826493
# 1                                                year  0.477591
# 2                              GraduationRate_5yr_All  0.414207
# 3                           GraduationRate_5yr_Female  0.379193
# 4                                   sat_avg_score_num  0.213952
# 5                            GraduationRate_4yr_White  0.200018
# 6                            lea_univ_college_courses  0.197152
# 7                              GraduationRate_5yr_SWD  0.176003
# 8                                  ACT_pTarget_PctMet  0.166518
# 9                            ACTMath_ACTBenchmark_All  0.152579
# 10                           GraduationRate_5yr_White  0.150274
# 11                            GraduationRate_5yr_Male  0.138957
# 12                                long_susp_per_c_num  0.127451
# 13                             lea_state_perpupil_num  0.125810
# 14                              lea_total_expense_num  0.122439
# 15                                  tchyrs_11plus_pct  0.121692
# 16                           GraduationRate_5yr_Asian  0.101050
# 17                             GraduationRate_4yr_AIG  0.098977
# 18                  Distinguished_TCHR_Standard 4_Pct  0.092455
# 19                          total_specialized_courses  0.092275
# 20                        ACTWriting_ACTBenchmark_LEP  0.091529
# 21                           lea_supplies_expense_pct  0.089676
# 22                         lea_instruct_equip_exp_pct  0.084499
# 23                  Distinguished_TCHR_Standard 1_Pct  0.079834
# 24                                    MinorityMalePct  0.064430
# 25                                          SPG Score  0.064035
# 26                                       TwoOrMorePct  0.061649
# 27                             stud_internet_comp_num  0.061230
# 28                         10+ Years_LEA_Exp_Pct_Prin  0.056160
# 29                                 tchyrs_4thru10_pct  0.052114
# 30                       ACTWorkKeys_SilverPlus_Asian  0.051142
# 31                             lea_local_perpupil_num  0.045374
# 32                               short_susp_per_c_num  0.045028
# 33                                    crime_per_c_num  0.038047
# 34                           binary_gender_ENROLL_sch  0.036662
# 35                           GraduationRate_4yr_Asian  0.030769
# 36                        ACTEnglish_ACTBenchmark_LEP  0.027675
# 37                        GraduationRate_4yr_Hispanic  0.027447
# 38                        ACTScience_ACTBenchmark_LEP  0.018007
# 39                             GraduationRate_5yr_EDS  0.017944
# 40                                        MinorityPct  0.017841
# 41                             GraduationRate_5yr_AIG  0.016926
# 42                             GraduationRate_5yr_LEP  0.012354
# 43            ACTCompositeScore_UNCMin_AmericanIndian  0.011250
# 44                  GraduationRate_4yr_TwoorMoreRaces  0.004523
# 45                                  tchyrs_0thru3_pct  0.002681
# 46                             GraduationRate_4yr_SWD  0.001373
# 47                  GraduationRate_5yr_TwoorMoreRaces  0.000824
# 48                           lea_federal_perpupil_num -0.000634
# 49                                 expelled_per_c_num -0.002225
# 50                         0-3 Years_LEA_Exp_Pct_Prin -0.002301
# 51                          GraduationRate_4yr_Female -0.003582
# 52                        GraduationRate_5yr_Hispanic -0.005321
# 53                             GraduationRate_4yr_LEP -0.020477
# 54                                flicensed_teach_pct -0.026180
# 55                                  ap_pct_3_or_above -0.027423
# 56                                 EVAAS Growth Score -0.029836
# 57                                  MinorityFemalePct -0.030771
# 58                            MathGr10_pTarget_PctMet -0.032666
# 59                        4-10 Years_LEA_Exp_Pct_Prin -0.037029
# 60                         lea_stud_internet_comp_num -0.049624
# 61                                          unit_code -0.053444
# 62                           lea_services_expense_pct -0.054533
# 63                               _1yr_tchr_trnovr_pct -0.055180
# 64                           ACTMath_ACTBenchmark_LEP -0.056154
# 65                               avg_daily_attend_pct -0.059220
# 66                                    lea_cte_courses -0.062867
# 67                           GraduationRate_5yr_Black -0.065529
# 68                             GraduationRate_4yr_EDS -0.080000
# 69                             lea_salary_expense_pct -0.091085
# 70                              sat_participation_pct -0.093713
# 71                           GraduationRate_4yr_Black -0.093884
# 72                               ap_participation_pct -0.094315
# 73                                    advance_dgr_pct -0.149126
# 74                                        SPG Grade_B -0.164282
# 75                            GraduationRate_4yr_Male -0.179631
# 76                               univ_college_courses -0.180155
# 77  calendar_type_txt_Regular School, Year-Round C... -0.193593
# 78                          ACTMath_ACTBenchmark_Male -0.201163

# %% [markdown]
# |     Statistics     |      Values     |      Description
# |     :-     |     -------------:     |     :-:
# |Accuracy|~98.69%|how often is the classifier correct?
# |Misclassification Rate(aka Error Rate)|~1.31% |how often is it wrong?
# |True Positive Rate(aka Sensitivity)|~99.59% |When it's actually yes, how often does it predict yes?
# | False Positive Rate|~19.44%|When it's actually no, how often does it predict yes?
# |Specificity|~80.56%|When it's actually no, how often does it predict no?
# |Precision|~99.04%|When it predicts yes, how often is it correct?
# |Prevalence|~95.28%|How often does the yes condition actually occur in our sample?
#
# Reference:http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/

# %%
# now let's make a pandas Series with the names and values, and plot them
# Sorting by series value
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.figure(figsize = (20,10))
# Need to update this to like the top 20
weights = pd.Series(lr_clf.coef_[0],index=df_feat.columns)
weights = weights.sort_values(ascending=False)
weights.plot(kind='bar')
plt.show()

# %% [markdown]
# ### Support Vector Machines

# %% [markdown]
# A Support Vector Machine (SVM) is a discriminative classifier formally defined by a separating hyperplane. In other words, given labeled training data (supervised learning), the algorithm outputs an optimal hyperplane which categorizes new examples. In two dimentional space this hyperplane is a line dividing a plane in two parts where in each class lay in either side.
#
# In simple words: **The ultimate goal of SVMs is the separation of classes.**
#
# Reference:https://medium.com/machine-learning-101/chapter-2-svm-support-vector-machine-theory-f0812effc72

# %% [markdown]
# The results below show that we have **an accuracy score of ~98.95%** which is **close to the logistic model accuracy, ~98.68%**. In the confusion matrix, there is a zero value at the lower left cell. This indicates that there is **no false negative**.
#
# The following is the list that are often generated from a confusion matrix for a binary classifier:
#
# |     Statistics     |      Values     |      Description
# |     :-     |     -------------:     |     :-:
# |Accuracy|~98.95%|how often is the classifier correct?
# |Misclassification Rate(aka Error Rate)|~1.05% |how often is it wrong?
# |True Positive Rate(aka Sensitivity)|100% |When it's actually yes, how often does it predict yes?
# | False Positive Rate|~22.22%|When it's actually no, how often does it predict yes?
# |Specificity|~77.78%|When it's actually no, how often does it predict no?
# |Precision|~98.91%|When it predicts yes, how often is it correct?
# |Prevalence|~95.28%|How often does the yes condition actually occur in our sample?
#
# Reference:http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/

# %% [markdown]
# The following is to get the SVM model. Accuracy score and confusion matrix are presented.

# %%
# lets investigate SVMs on the data and play with the parameters and kernels# lets in 
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('============================')
print('Accuracy Score is:\n',acc )
print('============================')
print('Confusion Matrix is:\n',conf)
# Out:
# ============================
# Accuracy Score is:
#  0.9881889763779528
# ============================
# Confusion Matrix is:
#  [[ 27   9]
#  [  0 726]]

# %% [markdown]
# Here is a brief summary of the support vectors.

# %%
# look at the support vectors
print('=============539 Support Vectors================')
print(svm_clf.support_vectors_.shape)
print('============Number of Support points============')
print(svm_clf.support_.shape)
print('====Number of Support Vectors for Each Class====')
print(svm_clf.n_support_ )
# Out:
# =============539 Support Vectors================
# (536, 79)
# ============Number of Support points============
# (536,)
# ====Number of Support Vectors for Each Class====
# [135 401]

# %% [markdown]
# Now we create a dataframe that has all the support vectors. Then create a new column named 'Going'. At last we add the support vectors back the the dataframe and the original data.

# %%
df_support = df_operation.loc[svm_clf.support_,:] # grab the support vectors and assign it to df_support
df_support['Likely Going'] = df_target[svm_clf.support_] # add back in the 'Going' Column to the dataframe
df_operation['Likely Going'] = df_target # also add it back in for the original data
df_support.info() # there are 539 entries
df_support.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536 entries, 30 to 3040
# Columns: 291 entries, student_num to Likely Going
# dtypes: float64(265), int64(25), object(1)
# memory usage: 1.2+ MB
#     student_num  lea_avg_student_num  st_avg_student_num  Biology_Size  \
# 30        257.0                855.0               837.0          16.0
# 40       1101.0                785.0               837.0          24.0
# 55        809.0                759.0               837.0          18.0
# 72        788.0                459.0               837.0          21.0
# 89        740.0                474.0               837.0          23.0
#
#     English II_Size  Math I_Size  lea_total_expense_num  \
# 30             19.0         17.0                8380.11
# 40             22.0         22.0                8303.73
# 55             19.0         16.0                8424.37
# 72             26.0         22.0                8475.92
# 89             21.0         21.0                8645.88
#
#     lea_salary_expense_pct  lea_services_expense_pct  \
# 30                   0.647                     0.054
# 40                   0.615                     0.070
# 55                   0.635                     0.056
# 72                   0.624                     0.077
# 89                   0.598                     0.090
#
#     lea_supplies_expense_pct      ...       SPG Grade_D  \
# 30                     0.071      ...                 0
# 40                     0.092      ...                 0
# 55                     0.083      ...                 0
# 72                     0.073      ...                 0
# 89                     0.100      ...                 0
#
#     EVAAS Growth Status_Met  EVAAS Growth Status_NotMet  unit_code  year  \
# 30                        1                           0     110322  2014
# 40                        0                           1     120318  2014
# 55                        1                           0     140348  2014
# 72                        1                           0     182316  2014
# 89                        1                           0     240371  2014
#
#       gender_college_enroll  ENROLL_sch_pct  binary_gender_ENROLL_sch  \
# 30  F_Female_ENROLL_sch_pct           64.28                         1
# 40  F_Female_ENROLL_sch_pct           72.88                         1
# 55  F_Female_ENROLL_sch_pct           75.72                         1
# 72  F_Female_ENROLL_sch_pct           70.51                         1
# 89  F_Female_ENROLL_sch_pct           56.70                         1
#
#     binary_ENROLL_sch_pct  Likely Going
# 30                      1             1
# 40                      1             1
# 55                      1             1
# 72                      1             1
# 89                      1             1
#
# [5 rows x 291 columns]

# %%
df_operation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3808 entries, 0 to 3807
# Columns: 291 entries, student_num to Likely Going
# dtypes: float64(265), int64(25), object(1)
# memory usage: 8.5+ MB

# %% [markdown]
# The plots as below show the comparison of the support vectors(left) and the the original feature(right).
#
# When looking at **lea_salary_expense_pct support vectors**, there are more 0s(class:not going to college) than the original dataset(Because we can see the left actually can reach 12, the right cannot.) and the amount of 1s(class:going to college) is also higher than the original.
#
# When looking at **SPG Score support vectors**, there are both less 0s(class:not going to college) and less 1s(class:going to college)than the original dataset.
#
# When looking at the plots of **ap_participation_pct**, there is a very obvious difference: while the rest of the plots are sharing a similar pattern between support vectors and original, plots for this variable is demonstrating different patterns.

# %%
# group the original data and the support vectors
df_grouped_support = df_support.groupby(['Likely Going'])
df_grouped = df_operation.groupby(['Likely Going'])

# plot KDE of Different variables
vars_to_plot = ['lea_salary_expense_pct','SPG Score','sat_participation_pct','ap_participation_pct',
                'sat_avg_score_num','ap_pct_3_or_above','avg_daily_attend_pct',
                'flicensed_teach_pct','10+ Years_LEA_Exp_Pct_Prin','MinorityFemalePct','MinorityMalePct',
                'GraduationRate_4yr_Female','GraduationRate_4yr_Female','year']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['Likely Going','Not Likely Going'])
    plt.title(v+' (Instances chosen as SVs)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['Likely Going','Not Likely Going'])
    plt.title(v+' (Original)')

# %% [markdown]
# ### Model Advantages

# %% [markdown]
# Sources:
# https://medium.com/@aneesha/recursive-feature-elimination-with-scikit-learn-3a2cbdf23fb7
#
# https://elitedatascience.com/machine-learning-algorithms
#
# http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/
#
# As mentioned in the section outlining our analysis strategy, we decided to conduct a binary classification task of measuring which school features contained in the North Carolina Public High Schools dataset represented the best predictors of whether or not student graduates were likely to enroll in college-level courses using techniques such as recursive feature elimination for preprocessing and modeling our predictions leveraging logistic regression and support vector machine (SVM) techniques. Before receiving model predictions using logistic regression and SVMs, we first had to construct a binary classifier because a binary response variable was not found in the original dataset. Thus, we decided to create two new binary responses.
#
# The first can be identified as college enrollment percentage (ENROLL_sch_pct), and the second is identified as college enrollment percentage by gender (binary_gender_ENROLL_sch).  After further analysis, we made the decision to focus on college enrollment percentage as our final response variable (ENROLL_sch_pct) for the project. Following identification of a primary binary response variable, we then performed recursive feature elimination to deduce our dataset down to twenty attributes from the original dataset before training our binary classifier. These twenty attributes would be selected using RFE based on their level of contribution for predicting college enrollment of student graduates. In essence, our reasoning for utilizing RFE was due to the high-dimensionality of the original dataset. This technique is often used to remove features of low importance which can improve model accuracy, provide a reduction in model complexity, and decrease risks of overfitting. Furthermore, once we decide to train our models using logistic regression and support vector machines, overall performance with regard to training time will be reduced.
#
# With regard to model advantages as well as disadvantages using classification techniques such as logistic regression and support vector machines, we did see some observable differences related to model accuracy. Before commenting on observed differences, it’s important to point out the inherent advantages and disadvantages of each technique. Although different from linear regression, logistic regression models are still “linear” in that they function well when classes are linearly separable; however, logistic regression can still be used when classes cannot be easily separated by single decision surface, but the costs from doing so results in coefficients being penalized.
#
# Some strengths (not exhaustive) of logistic regression are that model outputs will have a good probabilistic interpretation as well as the ability to normalize in order to avoid the pitfall of overfitting. Lastly, models using logistic regression can easily be appended with new data using functions such as stochastic gradient descent or SGD. In terms of weaknesses or disadvantages though, it’s not uncommon to observe underperforming models when classification boundaries are non-linear and/or contain multiple decision boundaries. The “linear” component to logistic regression does not contain the flexibility to naturally capture relationships that are higher in complexity.
#
# In the case of support vector machines, the primary benefit comes from kernels that are non-linear in order to model non-linear classification boundaries. Kernels are a mechanism used by support vector machines to measure distance between two observations.  The goal is to maximize or find the optimal distance between the closest members which each belong to different classes. Unlike logistic regression, support vector machines provide more flexibility when classifying non-linear decision boundaries. With several kernels to choose from, SVMs are robust when it comes to risks of overfitting. The robustness of SVMS really begins to show when modeling datasets with high dimensionality. Some disadvantages are the amount of memory used in processing, tuning models become more difficult due to the number of kernels present, and scalability becomes problematic when using on larger datasets.
#
# As stated above, we did observe and experience differences with both models using logistic regression and support vector machines. With regard to performance in terms of prediction accuracy, the model derived from using SVMs was slightly higher with an prediction accuracy percentage of 98.95% and the prediction accuracy percentage using logistic regression came in at 98.69%. Outside of prediction accuracy, our model using logistic regression did seem to perform better with regard to statistics such as false positive rates, specificity, and precision. SVM performed better in terms of a lower misclassification rate of 1.05%, whereas, logistic regression model had a misclassification rate of 1.31%. As it relates to training time or efficiency, our model utilizing SVM seemed to perform faster due to its enhanced flexibility of handling non-linear classification boundaries and/or complexity of relationships within the dataset. It seems the logistic regression model required more time to process due to the non-linearity of the model as well as the dimensionality of the dataset.

# %% [markdown]
# ### Interpret Feature Importance

# %%
# Use the weights from logistic regression to interpret the importance of different features for the classification task
# Explain your interpretation in detail
# Why do you think some variables are more important?

# %% [markdown]
# ### Interpret Support Vectors
